# %% [markdown]
# # MultiSensor Dataset Preparation
# - Experiment data: March 2024. Aluminum, Laser-Wire DED
# - Aurthor: Chen Lequn
#
# ### Notebook 3b: Feature selection, ML modelling and ablation study (feature-based audio model)
# - Full Dataset: All features (from previous notebook 2b)
# - Ablated Dataset 1: Features after removing those with Pearson correlation > 0.97 (within audio modality).
# - Ablated Dataset 2: Features after removing those with Pearson correlation > 0.9 (within audio modality).
# - Ablated Dataset 3: Features from Ablated Dataset 1 with MI > 0.05.
# - Ablated Dataset 4: Features from Ablated Dataset 1 with MI > 0.1.

# %%
import os
import glob
import sys
import math
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML
from pandas import DataFrame
import scipy as sp
import itertools
from collections import defaultdict
from pprint import pprint
import pickle

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pyplot import gca
from pylab import *
import seaborn as sns
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
# %matplotlib inline

# Scikit-learn general
from sklearn import preprocessing, metrics, svm, datasets, tree, neighbors
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, precision_score, recall_score, confusion_matrix, roc_curve, auc, classification_report
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_validate, KFold, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, scale
from sklearn.ensemble import HistGradientBoostingClassifier

# Scikit-learn models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, SVR
from sklearn.multiclass import OneVsRestClassifier

# Imbalanced learn
from imblearn.ensemble import BalancedRandomForestClassifier, RUSBoostClassifier

# XGBoost and LightGBM
import xgboost as xgb
from xgboost import XGBClassifier
import lightgbm as lgb
from lightgbm import LGBMClassifier

# Utilities
from scipy.stats import uniform, randint
from scipy.interpolate import griddata
from sklearn.utils import shuffle, resample, class_weight
from utils import *
from joblib import dump, load
np.random.seed(0)
# Out:
# /tmp/ipykernel_942875/2296993266.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
def display_left_wide(df, column_width=800):
    # Adjust the max column width
    pd.set_option('display.max_colwidth', column_width)

    # Display the dataframe on the left with custom column width
    left_aligned_df = '<div style="float: left;">{}</div>'.format(df.to_html())
    display(HTML(left_aligned_df))

# %%
PROJECT_ROOT_DIR = "../"

IMAGE_PATH = os.path.join(PROJECT_ROOT_DIR, "result_images", 'defect classification', 'ML-baseline', 'ablation study')
model_path = os.path.join(PROJECT_ROOT_DIR, "trained_models", 'defect classification', 'ML-baseline', 'ablation study')
scaler_path = os.path.join(PROJECT_ROOT_DIR, "saved_scalers", 'defect classification',  'ML-baseline', 'ablation study')
os.makedirs(IMAGE_PATH, exist_ok=True)
os.makedirs(model_path, exist_ok=True)
os.makedirs(scaler_path, exist_ok=True)

# Change to desirable location of the raw dataset
Multimodal_dataset_PATH = "/home/chenlequn/pan1/Dataset/Laser-Wire-DED-ThermalAudio-Dataset"
Annotation_file_path = os.path.join(Multimodal_dataset_PATH, "Annotation")
Dataset_path = os.path.join(Multimodal_dataset_PATH, 'Dataset')
final_audio_dataset = os.path.join(Multimodal_dataset_PATH, 'Dataset', "audio")
final_image_dataset = os.path.join(Multimodal_dataset_PATH, 'Dataset', "thermal_images")
              

## function for automatically save the diagram/graph into the folder 
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGE_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 2.50

# %%
# %store -r train_indices
# %store -r val_indices
# %store -r test_indices

# %%
val_indices
# Out:
# array([2923, 2390, 2534, 1233, 1674, 5064, 6125, 1136, 1514, 5402, 3271,
#        4890, 5684, 4870, 2757, 3607, 4408, 1248,  358,  973,  583, 2771,
#        4829, 2734, 3003,  265, 6025, 1166,  769,  802, 4688, 1866, 5542,
#        1926, 3313, 6178, 1994, 1448, 3238, 1557, 1112, 3486, 4330, 5103,
#        6136,  845, 1133, 1148, 2322, 2650,  496, 1511,  908, 1656, 1820,
#        4643, 1475, 5612, 2157,  864, 5799, 4218, 2452,  337,  844,  495,
#        1624, 2853,  453, 2562, 3694, 3094,  811, 5420, 3781, 4188, 2374,
#        2691, 3955, 6019, 2631,  440, 5759, 5153,  432, 3802, 3967, 2652,
#        2162, 2713, 4211, 5651, 3054, 1753, 5210, 3748, 5514, 2567, 4205,
#        2265,  714, 1719,  710, 4244, 6062,  857, 3554,  471, 4891, 4149,
#        5362, 1975, 2046, 4869, 5807, 4087,  127, 3148,  653,  394, 5272,
#         785, 4964,  288, 5483, 3766, 4291, 1901, 2441, 3664, 2344, 4144,
#        3557, 6150, 3245, 3533, 5741, 1533, 3596, 4308, 4728, 4541,  271,
#        2931, 6157, 4267,  678, 6171, 2110, 4061, 2433, 3630, 2471,  672,
#        3350, 3277, 3104, 3079, 3993, 2868, 3826, 4340,  300, 3690, 4337,
#        4780, 4830, 2616,  906, 6114, 5937, 2373,  191, 5116, 3991, 2174,
#        6053, 2759, 2450,  200, 5805, 4371,  677, 5640,  995, 1987, 1714,
#         619, 5387,  444, 4128, 4939, 3770, 5852,  125,  149, 3489, 1240,
#        4350, 2612, 4551, 5083, 4263, 2756, 6040, 2777, 5440, 3388, 3183,
#         830,  986, 4138,  553, 2180, 3911, 6086, 5550, 1181, 4758, 3088,
#        3754, 3372,  463, 4499, 3339, 3232, 1758, 2547, 6057, 6162,  393,
#        4133, 4361,  569,  630, 1867, 4692, 3531,  340, 2102, 5232, 4784,
#        1443, 1874, 3707,  865, 5693, 3296, 2011, 2849, 2098, 5597,  415,
#        4377, 2901, 2950, 3510, 1343, 3114, 1126, 1177, 3270, 3027, 4192,
#        4631, 3441, 2135, 3982, 2022, 1206, 4648, 4052, 4120, 5273, 5197,
#          86,  169, 2230, 4334, 2315, 5405,  491, 4682,  562, 3773,  117,
#        1243, 3093, 5017,  281, 1144, 4806, 5226, 2667,   92, 2741, 3468,
#        3971,  542, 4409, 4428,  132, 3714, 4816, 4298, 2800, 4167, 4232,
#        3419, 6034, 2621, 3083, 3227, 4096, 4837, 4075, 2479, 6009, 4395,
#        1620, 2331, 1535, 2749, 3349, 3586, 1982, 4754, 5493,  372, 2832,
#         544, 4372, 2962, 3547, 3106, 4582, 1113, 5569, 5666, 5985, 2261,
#        2491,  216, 2580, 6063, 2767, 4595, 4948,  334, 5553,  618, 2885,
#        5932, 2117, 4003, 2305, 1254, 5986, 5496, 4636, 1155, 4099, 3605,
#        3151, 1460, 3200, 1639,  326,  423, 2680, 3150, 4980, 5207, 3872,
#        2138, 4193,   61, 3023, 1337, 1239, 3745, 5487, 1100, 5918, 1369,
#        1139,  184, 5860,  207, 3789,  665,  576, 4173, 3575, 2996, 3052,
#        1381, 3057, 3149, 4368, 5033,  751, 2956, 6088, 1262, 5424, 4213,
#        5561, 1056, 5239,  801, 5131, 6005, 5074, 3888, 2924, 4622, 2109,
#        5351,  775,  499, 5678,  458, 3823, 3328, 2694, 3567, 4290, 2325,
#        4516, 4545, 3699, 3017, 5673, 1968,  341, 5429, 4317, 1235, 2019,
#        3816, 3946, 5384, 5915, 5582,  607,  667,  167, 1908, 3035,  732,
#        5118,  651, 1532, 4112, 4484, 1506, 3163, 4053, 3852,  261, 3626,
#        1440, 2263,  459, 5335, 1201, 6071, 2596, 1878, 2790, 4759, 4571,
#        2707, 2548, 6091, 3253, 2079, 4517, 5729, 2084, 3281, 1300, 4391,
#         917,  203, 2523,  196, 3711, 2769, 1320, 5680, 2535, 5092, 2818,
#        2301, 3256, 1985, 1603, 1562, 4229, 2285, 4302, 4376,  719, 5549,
#        3203, 1458, 5184, 2341, 3979,  902,  513, 1095, 1179, 2217, 5744,
#        2690, 2597, 4479, 2519, 1580, 4358, 1045, 4721, 5046,  411, 4195,
#        5913, 3159, 3787, 5507, 3463, 5204, 3522, 5071, 4345,  181, 2105,
#        3145, 3236, 3819, 1298, 4715, 2746, 1480, 3923,  532, 4397,  296,
#        1505, 1828, 1655, 4921, 1740,  204, 6119, 2840, 2050, 5936, 2718,
#        4236, 5327, 5713, 3362, 2000, 4930,  164, 4204, 1687, 5005, 5279,
#         571,    8, 1645, 5871, 1344, 2544, 4237, 5859,  257,  483, 1880,
#        1195, 4586, 3861, 5498, 5665, 2015, 4900, 3049, 1903, 4706,  242,
#        1058,  157, 2399, 3842, 4082, 5408, 3869, 4842, 2252, 3335, 1898,
#         682, 2557, 5178, 6135, 4170, 5951, 4332,  944, 1209, 4982, 2405,
#        3031, 1102])

# %% [markdown]
# ## Load Dataset

# %%
# %store -r datasets
# %store -r le
# %store -r Y_encoded

# %%
datasets
# Out:
# {'All Features': array([[ 3.17460597e-02,  3.89823429e-02,  1.43036339e-02, ...,
#           6.36536217e+00, -4.25530243e+00,  6.84352922e+00],
#         [ 4.69362400e-02,  5.34921885e-02,  1.87268574e-02, ...,
#           6.29292870e+00, -4.17497969e+00,  7.59553719e+00],
#         [ 2.42218133e-02,  3.33609357e-02,  1.39142405e-02, ...,
#           9.25216484e+00, -2.73436689e+00,  4.95732212e+00],
#         ...,
#         [ 1.22464793e-02,  1.48045355e-02,  5.10020321e-03, ...,
#           6.38746643e+00, -1.07345905e+01,  8.09787750e+00],
#         [ 1.33671844e-02,  1.65460929e-02,  5.38443821e-03, ...,
#           4.76326370e+00, -1.38471327e+01,  7.91168976e+00],
#         [ 1.29805105e-02,  1.56615954e-02,  5.63964201e-03, ...,
#           5.72218609e+00, -1.30503092e+01,  7.41869259e+00]]),
#  'Ablated 1': array([[ 1.43036339e-02,  6.43990934e-02, -3.72418060e+01, ...,
#           6.36536217e+00, -4.25530243e+00,  6.84352922e+00],
#         [ 1.87268574e-02,  3.37868482e-02, -3.70896606e+01, ...,
#           6.29292870e+00, -4.17497969e+00,  7.59553719e+00],
#         [ 1.39142405e-02,  4.39909287e-02, -4.28966522e+01, ...,
#           9.25216484e+00, -2.73436689e+00,  4.95732212e+00],
#         ...,
#         [ 5.10020321e-03,  9.38775539e-02, -4.31619720e+01, ...,
#           6.38746643e+00, -1.07345905e+01,  8.09787750e+00],
#         [ 5.38443821e-03,  8.73015895e-02, -4.29929543e+01, ...,
#           4.76326370e+00, -1.38471327e+01,  7.91168976e+00],
#         [ 5.63964201e-03,  7.64172301e-02, -4.37425652e+01, ...,
#           5.72218609e+00, -1.30503092e+01,  7.41869259e+00]]),
#  'Ablated 2': array([[ 4.36204793e+03,  1.83287519e+03,  8.32178332e-01, ...,
#           6.36536217e+00, -4.25530243e+00,  6.84352922e+00],
#         [ 5.76311407e+03,  1.86640804e+03,  9.84646681e-01, ...,
#           6.29292870e+00, -4.17497969e+00,  7.59553719e+00],
#         [ 2.67076349e+03,  2.52268078e+03,  1.18157602e+00, ...,
#           9.25216484e+00, -2.73436689e+00,  4.95732212e+00],
#         ...,
#         [ 4.06765411e+03,  1.42642163e+03,  5.21026049e-01, ...,
#           6.38746643e+00, -1.07345905e+01,  8.09787750e+00],
#         [ 3.54758739e+03,  1.33483516e+03,  3.64642275e-01, ...,
#           4.76326370e+00, -1.38471327e+01,  7.91168976e+00],
#         [ 4.60964967e+03,  1.93418746e+03,  4.07682457e-01, ...,
#           5.72218609e+00, -1.30503092e+01,  7.41869259e+00]]),
#  'Ablated 3': array([[ 4.36204793e+03,  1.83287519e+03,  8.32178332e-01, ...,
#           1.32639894e+01,  1.07600451e+01, -4.25530243e+00],
#         [ 5.76311407e+03,  1.86640804e+03,  9.84646681e-01, ...,
#           7.94448471e+00,  1.06096754e+01, -4.17497969e+00],
#         [ 2.67076349e+03,  2.52268078e+03,  1.18157602e+00, ...,
#           6.51386452e+00,  7.62946749e+00, -2.73436689e+00],
#         ...,
#         [ 4.06765411e+03,  1.42642163e+03,  5.21026049e-01, ...,
#           7.40068769e+00,  1.41501680e-01, -1.07345905e+01],
#         [ 3.54758739e+03,  1.33483516e+03,  3.64642275e-01, ...,
#           5.67995882e+00, -2.74140072e+00, -1.38471327e+01],
#         [ 4.60964967e+03,  1.93418746e+03,  4.07682457e-01, ...,
#           8.29096317e+00, -1.92537284e+00, -1.30503092e+01]]),
#  'Ablated 4': array([[ 4.36204793e+03,  1.83287519e+03,  8.32178332e-01, ...,
#           1.10472946e+01,  6.78420877e+00,  1.07600451e+01],
#         [ 5.76311407e+03,  1.86640804e+03,  9.84646681e-01, ...,
#           1.26649981e+01,  1.06953545e+01,  1.06096754e+01],
#         [ 2.67076349e+03,  2.52268078e+03,  1.18157602e+00, ...,
#           6.34147215e+00,  1.59727275e+00,  7.62946749e+00],
#         ...,
#         [ 4.06765411e+03,  1.42642163e+03,  5.21026049e-01, ...,
#           8.93326473e+00,  2.11701727e+00,  1.41501680e-01],
#         [ 3.54758739e+03,  1.33483516e+03,  3.64642275e-01, ...,
#           8.30215263e+00,  6.85348928e-01, -2.74140072e+00],
#         [ 4.60964967e+03,  1.93418746e+03,  4.07682457e-01, ...,
#           6.77566385e+00,  2.45746541e+00, -1.92537284e+00]])}

# %%
class_weights_encoded = class_weight.compute_class_weight('balanced',
                                                 classes = np.unique(Y_encoded),
                                                 y = Y_encoded)


class_names = (le.classes_).tolist()
print(f"class weights encoded: {class_weights_encoded}")
print(f"class        : {class_names}")
# Out:
# class weights encoded: [1.6284585  3.41436464 5.44493392 0.34515498 0.98800959]
# class        : ['Balling', 'Degradation', 'LOF', 'Laser-off', 'Non-defective']

# %%
# List of models
model_names = ['KNN', 'DT', 'RF', 'BalancedRF', 'RUSBoost', 'Ada', 'NN', 'XGBoost', 'LightGBM', 'SVM', 'HistGB']

# %% [markdown]
# ### Basic Evaluation Metrics

# %%
from joblib import dump, load
def evaluate_saved_models(model_path, datasets, kf, model_names, Y_encoded, train_indices, val_indices, test_indices, le, n_runs=10):
    """
    Load and evaluate pre-trained models.

    Parameters:
    - model_path (str): Directory where the pre-trained models are saved.
    - datasets (dict): Dictionary containing the names of datasets as keys and features as values.
    - kf (KFold): KFold cross-validator.
    - model_names (list): List of model names to evaluate.
    - Y_encoded (array): Array of encoded labels.
    - train_indices (array): Indices for training set.
    - val_indices (array): Indices for validation set.
    - test_indices (array): Indices for test set.
    - le (LabelEncoder): Pre-fitted LabelEncoder for class names.
    - n_runs (int): Number of runs to measure inference time.

    Returns:
    - final_results_df (DataFrame): DataFrame containing evaluation metrics.
    """
    # Create a dictionary to store final results
    final_results = defaultdict(list)
    
    # Create a dictionary to store temporary cross-validation results for each dataset and model
    cv_results = defaultdict(lambda: defaultdict(list))

    # Iterate over datasets and models
    for dataset_name, X in datasets.items():
        print(f"Processing dataset: {dataset_name}")
        
        # Split data
        X_train, X_val, X_test = X[train_indices], X[val_indices], X[test_indices]
        y_train, y_val, y_test = Y_encoded[train_indices], Y_encoded[val_indices], Y_encoded[test_indices]
        
        # Scaling
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
        
        # Load the model
        for model_name in model_names:
            print(f"Evaluating model: {model_name}")
            
            model_file = os.path.join(model_path, f"{model_name}_{dataset_name}.joblib")
            model = load(model_file)

            #### -------Loop through all models and measure inference time----------###
            # Initialize metrics for inference time
            inference_times = []
            times = []
            X_val_subset = X_val[:1000]
            for _ in range(n_runs):
                start_time = time.perf_counter()
                predictions = model.predict(X_val_subset)
                end_time = time.perf_counter()
                times.append(end_time - start_time)
            # Calculate average and standard deviation
            avg_time = np.mean(times)
            std_time = np.std(times)

            print(f"Inference Time: Mean = {avg_time:.6f} milliseconds, Std = {std_time:.6} milliseconds")
            cv_results[dataset_name][f"{model_name}_Inference Time_mean"] = avg_time
            cv_results[dataset_name][f"{model_name}_Inference Time_std"] = std_time
            ####-------Loop through all models and measure inference time----------###

            
            ###-------Confusion matrix: lass-specific accuracy-------------####
            # Initialize metrics for class-specific accuracy
            class_accuracies = defaultdict(list)
            # Calculate class-specific accuracies
            y_test_pred = model.predict(X_test)
            cm = confusion_matrix(y_test, y_test_pred)
            class_acc = cm.diagonal() / cm.sum(axis=1)
            for i, acc in enumerate(class_acc):
                class_name = le.inverse_transform([i])[0]  # Convert encoded class to original string name
                class_accuracies[class_name].append(acc)            
                
            # Calculate mean and std for class-specific accuracies
            for class_name, accuracies in class_accuracies.items():
                mean_acc = np.mean(accuracies)
                std_acc = np.std(accuracies)
                cv_results[dataset_name][f"{model_name}_{class_name}_mean"] = mean_acc
                cv_results[dataset_name][f"{model_name}_{class_name}_std"] = std_acc
                # Print the mean and std for the accuracy of the class "Keyhole pores" if it exists
                if class_name == "Balling":
                    print(f"Class 'Balling': Accuracy Mean = {mean_acc}, Std = {std_acc}")
                elif class_name == "Non-defective":
                    print(f"Class 'Non-defective': Accuracy Mean = {mean_acc}, Std = {std_acc}")
                elif class_name == "Laser-off":
                    print(f"Class 'Laser-off': Accuracy Mean = {mean_acc}, Std = {std_acc}")
            ###-------Confusion matrix: lass-specific accuracy-------------####
                    
            ###-------------5-fold cross-validation -----------
            # Initialize fold metrics
            fold_metrics = defaultdict(list)
            for train_idx, test_idx in kf.split(X_test):
                X_test_train, X_test_val = X_test[train_idx], X_test[test_idx]
                y_test_train, y_test_val = y_test[train_idx], y_test[test_idx]
                
                # Make predictions
                y_test_pred = model.predict(X_test_val)

                # Calculate metrics
                acc = accuracy_score(y_test_val, y_test_pred)
                f1 = f1_score(y_test_val, y_test_pred, average='weighted')
                precision = precision_score(y_test_val, y_test_pred, average='weighted')
                recall = recall_score(y_test_val, y_test_pred, average='weighted')

                try:
                    roc_auc = roc_auc_score(y_test_val, model.predict_proba(X_test_val), multi_class='ovr', average='weighted')
                except:
                    roc_auc = 'N/A'

                # Store the metrics for this fold
                fold_metrics['Accuracy'].append(acc)
                fold_metrics['F1 Score'].append(f1)
                fold_metrics['Precision'].append(precision)
                fold_metrics['Recall'].append(recall)
                fold_metrics['ROC-AUC'].append(roc_auc if roc_auc != 'N/A' else np.nan)
                    
            # -------Calculate mean and std for each metric------------
            for metric, values in fold_metrics.items():
                mean_val = np.nanmean(values)
                std_val = np.nanstd(values)
                print(f"{metric}: Mean = {mean_val}, Std = {std_val}")
                cv_results[dataset_name][f"{model_name}_{metric}_mean"] = mean_val
                cv_results[dataset_name][f"{model_name}_{metric}_std"] = std_val

    
    # Convert the temporary results to the final format
    for dataset_name, metrics in cv_results.items():
        final_results['Dataset'].append(dataset_name)
        for metric_name, value in metrics.items():
            final_results[metric_name].append(value)
    
    # Convert results to a DataFrame
    final_results_df = pd.DataFrame(final_results)

    return final_results_df

# %%
# Initialize KFold with the number of splits you desire
kf = KFold(n_splits=5)
final_results_df = evaluate_saved_models(model_path, datasets, kf, model_names, Y_encoded, train_indices, val_indices, test_indices, le, n_runs=20)
# Out:
# Processing dataset: All Features
# Evaluating model: KNN
# Inference Time: Mean = 0.006074 milliseconds, Std = 0.00283541 milliseconds
# Class 'Balling': Accuracy Mean = 0.6052631578947368, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9776536312849162, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.8963808025177027, Std = 0.02164586657491899
# F1 Score: Mean = 0.8888197940107098, Std = 0.02325504516280924
# Precision: Mean = 0.8983361878654448, Std = 0.027185702338996757
# Recall: Mean = 0.8963808025177027, Std = 0.02164586657491899
# ROC-AUC: Mean = 0.976665472178234, Std = 0.012687963471647828
# Evaluating model: DT
# Inference Time: Mean = 0.000077 milliseconds, Std = 1.86908e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.6578947368421053, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9553072625698324, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.872, Std = 0.0
# Accuracy: Mean = 0.8802911093627065, Std = 0.03550309917756507
# F1 Score: Mean = 0.8814234035773232, Std = 0.034618294039934806
# Precision: Mean = 0.8857213324175255, Std = 0.03448696453728613
# Recall: Mean = 0.8802911093627065, Std = 0.03550309917756507
# ROC-AUC: Mean = 0.9303414130503634, Std = 0.02881564511013659
# Evaluating model: RF
# Inference Time: Mean = 0.010559 milliseconds, Std = 0.000534706 milliseconds
# Class 'Balling': Accuracy Mean = 0.7105263157894737, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9142014162077106, Std = 0.012383912433977634
# F1 Score: Mean = 0.90767215389326, Std = 0.013315035189542064
# Precision: Mean = 0.9165342707506273, Std = 0.016738113399245327
# Recall: Mean = 0.9142014162077106, Std = 0.012383912433977634
# ROC-AUC: Mean = 0.9879050550263809, Std = 0.0036116341041781434
# Evaluating model: BalancedRF
# Inference Time: Mean = 0.006240 milliseconds, Std = 0.000168384 milliseconds
# Class 'Balling': Accuracy Mean = 0.6710526315789473, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9217877094972067, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.896, Std = 0.0
# Accuracy: Mean = 0.8770259638080251, Std = 0.024258709532292335
# F1 Score: Mean = 0.8807124593035127, Std = 0.022130902594163348
# Precision: Mean = 0.8890962837312685, Std = 0.019369789019825324
# Recall: Mean = 0.8770259638080251, Std = 0.024258709532292335
# ROC-AUC: Mean = 0.9832266152041214, Std = 0.0048395383850325996
# Evaluating model: RUSBoost
# Inference Time: Mean = 0.011073 milliseconds, Std = 0.000238778 milliseconds
# Class 'Balling': Accuracy Mean = 0.6578947368421053, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9385474860335196, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.776, Std = 0.0
# Accuracy: Mean = 0.8623918174665617, Std = 0.020302407629187138
# F1 Score: Mean = 0.8673737185824294, Std = 0.020827643275748695
# Precision: Mean = 0.880595665484843, Std = 0.022569208248148884
# Recall: Mean = 0.8623918174665617, Std = 0.020302407629187138
# ROC-AUC: Mean = 0.9591785029958292, Std = 0.003403630490501739
# Evaluating model: Ada
# Inference Time: Mean = 0.017933 milliseconds, Std = 0.000348275 milliseconds
# Class 'Balling': Accuracy Mean = 0.618421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9553072625698324, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.872, Std = 0.0
# Accuracy: Mean = 0.8689352216102806, Std = 0.018652893828120597
# F1 Score: Mean = 0.8669930669251567, Std = 0.016972950534645412
# Precision: Mean = 0.8706440763787235, Std = 0.017419012251987387
# Recall: Mean = 0.8689352216102806, Std = 0.018652893828120597
# ROC-AUC: Mean = 0.9667262655421316, Std = 0.006897389593939859
# Evaluating model: NN
# Inference Time: Mean = 0.001018 milliseconds, Std = 0.000135672 milliseconds
# Class 'Balling': Accuracy Mean = 0.7368421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.922292158405455, Std = 0.011238597221506899
# F1 Score: Mean = 0.920172063865228, Std = 0.01280223456201785
# Precision: Mean = 0.9213422687522229, Std = 0.014320510319385341
# Recall: Mean = 0.922292158405455, Std = 0.011238597221506899
# ROC-AUC: Mean = 0.9905015556169581, Std = 0.0037411437933869943
# Evaluating model: XGBoost
# Inference Time: Mean = 0.005446 milliseconds, Std = 0.0158511 milliseconds
# Class 'Balling': Accuracy Mean = 0.7631578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.9239181746656175, Std = 0.008528978027737989
# F1 Score: Mean = 0.9210350851365275, Std = 0.01044126924411335
# Precision: Mean = 0.9234550799979833, Std = 0.014077237113345721
# Recall: Mean = 0.9239181746656175, Std = 0.008528978027737989
# ROC-AUC: Mean = 0.9896048681904832, Std = 0.003822814875151419
# Evaluating model: LightGBM
# Inference Time: Mean = 0.001003 milliseconds, Std = 0.00068158 milliseconds
# Class 'Balling': Accuracy Mean = 0.7105263157894737, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9860335195530726, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.920718594282717, Std = 0.005950977587627641
# F1 Score: Mean = 0.9169887433853594, Std = 0.0076836837402589914
# Precision: Mean = 0.9188861541145531, Std = 0.009996287796707795
# Recall: Mean = 0.920718594282717, Std = 0.005950977587627641
# ROC-AUC: Mean = 0.9893837599175825, Std = 0.003593274785910219
# Evaluating model: SVM
# Inference Time: Mean = 0.010219 milliseconds, Std = 0.00105509 milliseconds
# Class 'Balling': Accuracy Mean = 0.6842105263157895, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.904, Std = 0.0
# Accuracy: Mean = 0.9077629163388409, Std = 0.004042006429461662
# F1 Score: Mean = 0.9044979894552666, Std = 0.006203255798967292
# Precision: Mean = 0.9092547606076284, Std = 0.010349255179754489
# Recall: Mean = 0.9077629163388409, Std = 0.004042006429461662
# ROC-AUC: Mean = 0.9823994788424143, Std = 0.0060374166251433315
# Evaluating model: HistGB
# Inference Time: Mean = 0.003596 milliseconds, Std = 0.000965623 milliseconds
# Class 'Balling': Accuracy Mean = 0.75, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.922292158405455, Std = 0.01337011310530181
# F1 Score: Mean = 0.9182325416696875, Std = 0.015239985187788754
# Precision: Mean = 0.923791581140765, Std = 0.012450000513211705
# Recall: Mean = 0.922292158405455, Std = 0.01337011310530181
# ROC-AUC: Mean = 0.9908761610842648, Std = 0.003710968053556127
# Processing dataset: Ablated 1
# Evaluating model: KNN
# Inference Time: Mean = 0.004806 milliseconds, Std = 0.000773556 milliseconds
# Class 'Balling': Accuracy Mean = 0.6447368421052632, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9748603351955307, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.92, Std = 0.0
# Accuracy: Mean = 0.8947810123262523, Std = 0.017195453498891785
# F1 Score: Mean = 0.8851137384869361, Std = 0.02172039806877993
# Precision: Mean = 0.8911242425370556, Std = 0.025427079474722676
# Recall: Mean = 0.8947810123262523, Std = 0.017195453498891785
# ROC-AUC: Mean = 0.9754707681368385, Std = 0.014078292831973191
# Evaluating model: DT
# Inference Time: Mean = 0.000117 milliseconds, Std = 1.33227e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.6447368421052632, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9664804469273743, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.856, Std = 0.0
# Accuracy: Mean = 0.8721872541306059, Std = 0.0056192986107534496
# F1 Score: Mean = 0.8703726147390324, Std = 0.005836453680365216
# Precision: Mean = 0.8753838132819259, Std = 0.008991869587724494
# Recall: Mean = 0.8721872541306059, Std = 0.0056192986107534496
# ROC-AUC: Mean = 0.9373191181820708, Std = 0.017515526796020153
# Evaluating model: RF
# /home/chenlequn/anaconda3/envs/working_primary/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Inference Time: Mean = 0.011121 milliseconds, Std = 0.000419772 milliseconds
# Class 'Balling': Accuracy Mean = 0.7105263157894737, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9142014162077106, Std = 0.013393127167715325
# F1 Score: Mean = 0.9075111788792759, Std = 0.014815920791746802
# Precision: Mean = 0.9145549533684433, Std = 0.016918355742206112
# Recall: Mean = 0.9142014162077106, Std = 0.013393127167715325
# ROC-AUC: Mean = 0.9882808453347603, Std = 0.005450230369489313
# Evaluating model: BalancedRF
# Inference Time: Mean = 0.006148 milliseconds, Std = 0.00023495 milliseconds
# Class 'Balling': Accuracy Mean = 0.6578947368421053, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9217877094972067, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.92, Std = 0.0
# Accuracy: Mean = 0.8802911093627065, Std = 0.025731983669630788
# F1 Score: Mean = 0.882589232045986, Std = 0.025158647112889346
# Precision: Mean = 0.8905297193340763, Std = 0.02459619671419118
# Recall: Mean = 0.8802911093627065, Std = 0.025731983669630788
# ROC-AUC: Mean = 0.983303472105342, Std = 0.004165823135456744
# Evaluating model: RUSBoost
# Inference Time: Mean = 0.010818 milliseconds, Std = 0.000313554 milliseconds
# Class 'Balling': Accuracy Mean = 0.6447368421052632, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.8743016759776536, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.728, Std = 0.0
# Accuracy: Mean = 0.8057959611854184, Std = 0.024296828516254688
# F1 Score: Mean = 0.8189689470296582, Std = 0.0214218803370277
# Precision: Mean = 0.8455421945748421, Std = 0.017433486482294674
# Recall: Mean = 0.8057959611854184, Std = 0.024296828516254688
# ROC-AUC: Mean = 0.935520598074878, Std = 0.005160782880506387
# Evaluating model: Ada
# Inference Time: Mean = 0.017350 milliseconds, Std = 0.000328302 milliseconds
# Class 'Balling': Accuracy Mean = 0.5657894736842105, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9608938547486033, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.864, Std = 0.0
# Accuracy: Mean = 0.8722528193023866, Std = 0.02832356533078624
# F1 Score: Mean = 0.8701169534917549, Std = 0.028179178104064152
# Precision: Mean = 0.87299144356015, Std = 0.027871425133271142
# Recall: Mean = 0.8722528193023866, Std = 0.02832356533078624
# ROC-AUC: Mean = 0.972174140679724, Std = 0.007573776118040758
# Evaluating model: NN
# Inference Time: Mean = 0.000985 milliseconds, Std = 7.7678e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.868421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9720670391061452, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9368607395751377, Std = 0.02592715838069736
# F1 Score: Mean = 0.9363964132571437, Std = 0.02684992254554504
# Precision: Mean = 0.9400662939011319, Std = 0.026574194886939986
# Recall: Mean = 0.9368607395751377, Std = 0.02592715838069736
# ROC-AUC: Mean = 0.9914176809914863, Std = 0.005442045669665763
# Evaluating model: XGBoost
# Inference Time: Mean = 0.006109 milliseconds, Std = 0.00501931 milliseconds
# Class 'Balling': Accuracy Mean = 0.8026315789473685, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.952, Std = 0.0
# Accuracy: Mean = 0.9336349331235247, Std = 0.013040212165772768
# F1 Score: Mean = 0.9315036934551971, Std = 0.013887389296563635
# Precision: Mean = 0.9348238583234199, Std = 0.013797015479233208
# Recall: Mean = 0.9336349331235247, Std = 0.013040212165772768
# ROC-AUC: Mean = 0.9893123080817114, Std = 0.0038297785952334075
# Evaluating model: LightGBM
# Inference Time: Mean = 0.001223 milliseconds, Std = 0.00160175 milliseconds
# Class 'Balling': Accuracy Mean = 0.7631578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.92, Std = 0.0
# Accuracy: Mean = 0.9255310778914241, Std = 0.014119176213013462
# F1 Score: Mean = 0.9227610378983719, Std = 0.015419446050191696
# Precision: Mean = 0.9271955653842037, Std = 0.017576050297312677
# Recall: Mean = 0.9255310778914241, Std = 0.014119176213013462
# ROC-AUC: Mean = 0.9907051738572106, Std = 0.0031957212908325034
# Evaluating model: SVM
# Inference Time: Mean = 0.008179 milliseconds, Std = 0.00109007 milliseconds
# Class 'Balling': Accuracy Mean = 0.6973684210526315, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.912, Std = 0.0
# Accuracy: Mean = 0.9045108838185156, Std = 0.02260972336324438
# F1 Score: Mean = 0.8986446240985385, Std = 0.027413652454286654
# Precision: Mean = 0.9068488142847901, Std = 0.026647287333607075
# Recall: Mean = 0.9045108838185156, Std = 0.02260972336324438
# ROC-AUC: Mean = 0.9845597080069209, Std = 0.00668850000719993
# Evaluating model: HistGB
# Inference Time: Mean = 0.003387 milliseconds, Std = 0.000126595 milliseconds
# Class 'Balling': Accuracy Mean = 0.7894736842105263, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.944, Std = 0.0
# Accuracy: Mean = 0.9320089168633622, Std = 0.013310343521515385
# F1 Score: Mean = 0.9293187919291725, Std = 0.014920578278982407
# Precision: Mean = 0.9331570608032109, Std = 0.017434016873553698
# Recall: Mean = 0.9320089168633622, Std = 0.013310343521515385
# ROC-AUC: Mean = 0.9916402382216567, Std = 0.0023843267607924655
# Processing dataset: Ablated 2
# Evaluating model: KNN
# Inference Time: Mean = 0.003942 milliseconds, Std = 0.000468952 milliseconds
# Class 'Balling': Accuracy Mean = 0.618421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9748603351955307, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.92, Std = 0.0
# Accuracy: Mean = 0.8931549960660897, Std = 0.022732366959273418
# F1 Score: Mean = 0.8843764260455919, Std = 0.027541030413951926
# Precision: Mean = 0.8919748018706214, Std = 0.02525338882902802
# Recall: Mean = 0.8931549960660897, Std = 0.022732366959273418
# ROC-AUC: Mean = 0.9727385837485911, Std = 0.012223965537178399
# Evaluating model: DT
# Inference Time: Mean = 0.000069 milliseconds, Std = 1.4717e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.6973684210526315, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9581005586592178, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.864, Std = 0.0
# Accuracy: Mean = 0.8770521898767374, Std = 0.02049779097766538
# F1 Score: Mean = 0.8766747434706353, Std = 0.023026499295754427
# Precision: Mean = 0.880597876709244, Std = 0.023318604090327842
# Recall: Mean = 0.8770521898767374, Std = 0.02049779097766538
# ROC-AUC: Mean = 0.9284364810041655, Std = 0.01894070433802506
# Evaluating model: RF
# Inference Time: Mean = 0.010869 milliseconds, Std = 0.000377198 milliseconds
# Class 'Balling': Accuracy Mean = 0.7368421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.952, Std = 0.0
# Accuracy: Mean = 0.9206661421452924, Std = 0.015095830856613616
# F1 Score: Mean = 0.9146035122294075, Std = 0.016371348759877252
# Precision: Mean = 0.9234387405474287, Std = 0.018537965499601707
# Recall: Mean = 0.9206661421452924, Std = 0.015095830856613616
# ROC-AUC: Mean = 0.9877798224194116, Std = 0.0044245019957853985
# Evaluating model: BalancedRF
# Inference Time: Mean = 0.006354 milliseconds, Std = 0.000177293 milliseconds
# Class 'Balling': Accuracy Mean = 0.6973684210526315, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9106145251396648, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.8786388670338316, Std = 0.03249776613215057
# F1 Score: Mean = 0.8820469564514715, Std = 0.02958600961009678
# Precision: Mean = 0.8920333610034608, Std = 0.025374318072802823
# Recall: Mean = 0.8786388670338316, Std = 0.03249776613215057
# ROC-AUC: Mean = 0.9814057962406922, Std = 0.006927054091361016
# Evaluating model: RUSBoost
# Inference Time: Mean = 0.010207 milliseconds, Std = 0.000246938 milliseconds
# Class 'Balling': Accuracy Mean = 0.5789473684210527, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.8994413407821229, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.664, Std = 0.0
# Accuracy: Mean = 0.8025832677681615, Std = 0.022152413684575677
# F1 Score: Mean = 0.8181267864829467, Std = 0.02019399435044584
# Precision: Mean = 0.8504966514415127, Std = 0.021343772585295653
# Recall: Mean = 0.8025832677681615, Std = 0.022152413684575677
# ROC-AUC: Mean = 0.9500875675040545, Std = 0.005489843471224845
# Evaluating model: Ada
# Inference Time: Mean = 0.017264 milliseconds, Std = 0.000448228 milliseconds
# Class 'Balling': Accuracy Mean = 0.5131578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.952513966480447, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.864, Std = 0.0
# Accuracy: Mean = 0.8560844479412537, Std = 0.027722579753924205
# F1 Score: Mean = 0.8541982589063235, Std = 0.027107757583224475
# Precision: Mean = 0.855868893730908, Std = 0.02712425606682879
# Recall: Mean = 0.8560844479412537, Std = 0.027722579753924205
# ROC-AUC: Mean = 0.9650897372854507, Std = 0.009468996047963195
# Evaluating model: NN
# Inference Time: Mean = 0.000973 milliseconds, Std = 7.84968e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.8157894736842105, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9888268156424581, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.935234723314975, Std = 0.013723302623111049
# F1 Score: Mean = 0.9328696746713112, Std = 0.01555436053320674
# Precision: Mean = 0.9352184622049204, Std = 0.015001924611986907
# Recall: Mean = 0.935234723314975, Std = 0.013723302623111049
# ROC-AUC: Mean = 0.9917871250998689, Std = 0.005407376252809054
# Evaluating model: XGBoost
# Inference Time: Mean = 0.005840 milliseconds, Std = 0.00707281 milliseconds
# Class 'Balling': Accuracy Mean = 0.7894736842105263, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9860335195530726, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.930422239706268, Std = 0.003928092559764148
# F1 Score: Mean = 0.9284922261489083, Std = 0.005272540301412712
# Precision: Mean = 0.9295786156060876, Std = 0.007274308993385801
# Recall: Mean = 0.930422239706268, Std = 0.003928092559764148
# ROC-AUC: Mean = 0.9888798568832626, Std = 0.006091895484494062
# Evaluating model: LightGBM
# Inference Time: Mean = 0.001034 milliseconds, Std = 0.00039115 milliseconds
# Class 'Balling': Accuracy Mean = 0.7763157894736842, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9860335195530726, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9287831104117492, Std = 0.009607872935421627
# F1 Score: Mean = 0.9253419226602144, Std = 0.011694885222237439
# Precision: Mean = 0.9315562909724469, Std = 0.014689011350605394
# Recall: Mean = 0.9287831104117492, Std = 0.009607872935421627
# ROC-AUC: Mean = 0.9894069791449093, Std = 0.004517859982402801
# Evaluating model: SVM
# Inference Time: Mean = 0.006853 milliseconds, Std = 0.00097812 milliseconds
# Class 'Balling': Accuracy Mean = 0.6578947368421053, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9860335195530726, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.9060844479412535, Std = 0.019188881659770448
# F1 Score: Mean = 0.8982703167902131, Std = 0.021393989001724602
# Precision: Mean = 0.8997074137644244, Std = 0.02468205855495408
# Recall: Mean = 0.9060844479412535, Std = 0.019188881659770448
# ROC-AUC: Mean = 0.9868445501483564, Std = 0.0036968767154860536
# Evaluating model: HistGB
# Inference Time: Mean = 0.003467 milliseconds, Std = 0.000138386 milliseconds
# Class 'Balling': Accuracy Mean = 0.8026315789473685, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.9271702071859428, Std = 0.011538233369566516
# F1 Score: Mean = 0.9239067355186779, Std = 0.013281884427873673
# Precision: Mean = 0.9302745039224645, Std = 0.017550964531306404
# Recall: Mean = 0.9271702071859428, Std = 0.011538233369566516
# ROC-AUC: Mean = 0.9906594794673718, Std = 0.0033270977054271895
# Processing dataset: Ablated 3
# Evaluating model: KNN
# Inference Time: Mean = 0.003365 milliseconds, Std = 0.000551324 milliseconds
# Class 'Balling': Accuracy Mean = 0.7631578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.912, Std = 0.0
# Accuracy: Mean = 0.9174141096249672, Std = 0.019000628411421222
# F1 Score: Mean = 0.9111401294623901, Std = 0.02218445051401388
# Precision: Mean = 0.9213964656261894, Std = 0.017919247316447718
# Recall: Mean = 0.9174141096249672, Std = 0.019000628411421222
# ROC-AUC: Mean = 0.9804446260515748, Std = 0.007868995602558243
# Evaluating model: DT
# Inference Time: Mean = 0.000064 milliseconds, Std = 1.44033e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.7368421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9497206703910615, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.88, Std = 0.0
# Accuracy: Mean = 0.8818384474167322, Std = 0.02166320901145229
# F1 Score: Mean = 0.8808479350197767, Std = 0.022775950380371498
# Precision: Mean = 0.8862094121662547, Std = 0.024165822456262892
# Recall: Mean = 0.8818384474167322, Std = 0.02166320901145229
# ROC-AUC: Mean = 0.9455660168231006, Std = 0.017160614668974308
# Evaluating model: RF
# /home/chenlequn/anaconda3/envs/working_primary/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Inference Time: Mean = 0.011169 milliseconds, Std = 0.000256928 milliseconds
# Class 'Balling': Accuracy Mean = 0.7105263157894737, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.944, Std = 0.0
# Accuracy: Mean = 0.919066351953842, Std = 0.009123939620733958
# F1 Score: Mean = 0.9129654059500991, Std = 0.011114398808312729
# Precision: Mean = 0.9217974624376971, Std = 0.01471833332262323
# Recall: Mean = 0.919066351953842, Std = 0.009123939620733958
# ROC-AUC: Mean = 0.9887108552351668, Std = 0.005479314087237881
# Evaluating model: BalancedRF
# Inference Time: Mean = 0.006233 milliseconds, Std = 0.000218775 milliseconds
# Class 'Balling': Accuracy Mean = 0.7236842105263158, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9050279329608939, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.912, Std = 0.0
# Accuracy: Mean = 0.8753999475478625, Std = 0.03538424456285748
# F1 Score: Mean = 0.8799483903551554, Std = 0.0323054923215729
# Precision: Mean = 0.8918925370109552, Std = 0.027919249271477785
# Recall: Mean = 0.8753999475478625, Std = 0.03538424456285748
# ROC-AUC: Mean = 0.982828742115967, Std = 0.006604228950033924
# Evaluating model: RUSBoost
# Inference Time: Mean = 0.010015 milliseconds, Std = 0.000147154 milliseconds
# Class 'Balling': Accuracy Mean = 0.8026315789473685, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.8603351955307262, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.688, Std = 0.0
# Accuracy: Mean = 0.8010228166797797, Std = 0.01429569750480093
# F1 Score: Mean = 0.8099831447263194, Std = 0.011527544001047158
# Precision: Mean = 0.8390578302503261, Std = 0.01349262115429572
# Recall: Mean = 0.8010228166797797, Std = 0.01429569750480093
# ROC-AUC: Mean = 0.9402589563859207, Std = 0.011230893671260293
# Evaluating model: Ada
# Inference Time: Mean = 0.015754 milliseconds, Std = 0.000414508 milliseconds
# Class 'Balling': Accuracy Mean = 0.618421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9608938547486033, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.832, Std = 0.0
# Accuracy: Mean = 0.8673747705218988, Std = 0.019137052899036992
# F1 Score: Mean = 0.8645920714014125, Std = 0.01847355605166533
# Precision: Mean = 0.868815275961083, Std = 0.022399746324750548
# Recall: Mean = 0.8673747705218988, Std = 0.019137052899036992
# ROC-AUC: Mean = 0.9643015198368456, Std = 0.009760399939911481
# Evaluating model: NN
# Inference Time: Mean = 0.000952 milliseconds, Std = 8.98146e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.7763157894736842, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.944, Std = 0.0
# Accuracy: Mean = 0.9271308680828744, Std = 0.020724054561055066
# F1 Score: Mean = 0.923708425992406, Std = 0.022061330945328514
# Precision: Mean = 0.9280343189890192, Std = 0.023369903180037836
# Recall: Mean = 0.9271308680828744, Std = 0.020724054561055066
# ROC-AUC: Mean = 0.9926261227472427, Std = 0.004125206407132233
# Evaluating model: XGBoost
# Inference Time: Mean = 0.009524 milliseconds, Std = 0.00592132 milliseconds
# Class 'Balling': Accuracy Mean = 0.8026315789473685, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9287699973773933, Std = 0.014120406197113104
# F1 Score: Mean = 0.9247058431295301, Std = 0.01732969889792068
# Precision: Mean = 0.9306273119839945, Std = 0.019571265350975454
# Recall: Mean = 0.9287699973773933, Std = 0.014120406197113104
# ROC-AUC: Mean = 0.9885654822329956, Std = 0.008565444864339043
# Evaluating model: LightGBM
# Inference Time: Mean = 0.000939 milliseconds, Std = 5.03052e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.7763157894736842, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9255573039601364, Std = 0.01401645366219056
# F1 Score: Mean = 0.922064893829744, Std = 0.01627553603004158
# Precision: Mean = 0.929209762345405, Std = 0.017735506398283397
# Recall: Mean = 0.9255573039601364, Std = 0.01401645366219056
# ROC-AUC: Mean = 0.9899196103272917, Std = 0.005231809938367762
# Evaluating model: SVM
# Inference Time: Mean = 0.004131 milliseconds, Std = 0.000692625 milliseconds
# Class 'Balling': Accuracy Mean = 0.7236842105263158, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9692737430167597, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.88, Std = 0.0
# Accuracy: Mean = 0.898072383949646, Std = 0.01487457444932868
# F1 Score: Mean = 0.8973839843317398, Std = 0.014480432214046312
# Precision: Mean = 0.9005997511283411, Std = 0.01478182162067929
# Recall: Mean = 0.898072383949646, Std = 0.01487457444932868
# ROC-AUC: Mean = 0.98833305396553, Std = 0.003835651521729101
# Evaluating model: HistGB
# Inference Time: Mean = 0.003679 milliseconds, Std = 0.000138221 milliseconds
# Class 'Balling': Accuracy Mean = 0.8157894736842105, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9804469273743017, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9320089168633622, Std = 0.013310343521515385
# F1 Score: Mean = 0.9291601454671877, Std = 0.014950813598931488
# Precision: Mean = 0.9355084243583534, Std = 0.016268193864530923
# Recall: Mean = 0.9320089168633622, Std = 0.013310343521515385
# ROC-AUC: Mean = 0.9901734857405773, Std = 0.0037453420036968614
# Processing dataset: Ablated 4
# Evaluating model: KNN
# Inference Time: Mean = 0.003632 milliseconds, Std = 0.00118854 milliseconds
# Class 'Balling': Accuracy Mean = 0.7368421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9860335195530726, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.936, Std = 0.0
# Accuracy: Mean = 0.9238919485969053, Std = 0.019755272604553373
# F1 Score: Mean = 0.9179475740178962, Std = 0.0239095926762215
# Precision: Mean = 0.9281764819054061, Std = 0.01802256194690374
# Recall: Mean = 0.9238919485969053, Std = 0.019755272604553373
# ROC-AUC: Mean = 0.9772771097507084, Std = 0.012039791995639025
# Evaluating model: DT
# Inference Time: Mean = 0.000061 milliseconds, Std = 1.40825e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.75, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.946927374301676, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.8, Std = 0.0
# Accuracy: Mean = 0.8689483346446367, Std = 0.024051835963329393
# F1 Score: Mean = 0.8711702724281251, Std = 0.026327108055388595
# Precision: Mean = 0.8864688017224968, Std = 0.020911510676906584
# Recall: Mean = 0.8689483346446367, Std = 0.024051835963329393
# ROC-AUC: Mean = 0.9392857760694543, Std = 0.018662568794938782
# Evaluating model: RF
# Inference Time: Mean = 0.011204 milliseconds, Std = 0.000234398 milliseconds
# Class 'Balling': Accuracy Mean = 0.6973684210526315, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9860335195530726, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.944, Std = 0.0
# Accuracy: Mean = 0.9206792551796485, Std = 0.01098167892730493
# F1 Score: Mean = 0.9156643550828292, Std = 0.012290006624282994
# Precision: Mean = 0.919794551178623, Std = 0.015549798404172206
# Recall: Mean = 0.9206792551796485, Std = 0.01098167892730493
# ROC-AUC: Mean = 0.9872694582579994, Std = 0.008450930601318596
# Evaluating model: BalancedRF
# Inference Time: Mean = 0.006288 milliseconds, Std = 0.000106375 milliseconds
# Class 'Balling': Accuracy Mean = 0.6973684210526315, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9078212290502793, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.92, Std = 0.0
# Accuracy: Mean = 0.8737739312877, Std = 0.028386839212871346
# F1 Score: Mean = 0.8781063591182482, Std = 0.02528956585425769
# Precision: Mean = 0.8888628807139962, Std = 0.020716841159900592
# Recall: Mean = 0.8737739312877, Std = 0.028386839212871346
# ROC-AUC: Mean = 0.9819234361173714, Std = 0.007088717722514286
# Evaluating model: RUSBoost
# Inference Time: Mean = 0.009849 milliseconds, Std = 0.000111268 milliseconds
# Class 'Balling': Accuracy Mean = 0.7894736842105263, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9078212290502793, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.72, Std = 0.0
# Accuracy: Mean = 0.830146865984789, Std = 0.03442079351356833
# F1 Score: Mean = 0.8344478458584407, Std = 0.030645753224686878
# Precision: Mean = 0.8559499520126803, Std = 0.032198450114386684
# Recall: Mean = 0.830146865984789, Std = 0.03442079351356833
# ROC-AUC: Mean = 0.9514678229557958, Std = 0.011067800307344427
# Evaluating model: Ada
# Inference Time: Mean = 0.016151 milliseconds, Std = 0.000682739 milliseconds
# Class 'Balling': Accuracy Mean = 0.6447368421052632, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9748603351955307, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.816, Std = 0.0
# Accuracy: Mean = 0.8722134801993182, Std = 0.017667009718597408
# F1 Score: Mean = 0.8656622750231537, Std = 0.019257758699072702
# Precision: Mean = 0.8694419539660109, Std = 0.024848123761710632
# Recall: Mean = 0.8722134801993182, Std = 0.017667009718597408
# ROC-AUC: Mean = 0.9604019223850774, Std = 0.01570555052721533
# Evaluating model: NN
# Inference Time: Mean = 0.000966 milliseconds, Std = 9.79661e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.7631578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9776536312849162, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.944, Std = 0.0
# Accuracy: Mean = 0.9255310778914241, Std = 0.012137627470712193
# F1 Score: Mean = 0.9219585842929051, Std = 0.01441898130651128
# Precision: Mean = 0.9249485673682191, Std = 0.016965229712080587
# Recall: Mean = 0.9255310778914241, Std = 0.012137627470712193
# ROC-AUC: Mean = 0.9918565548850766, Std = 0.0029095841533019937
# Evaluating model: XGBoost
# Inference Time: Mean = 0.005353 milliseconds, Std = 0.00586774 milliseconds
# Class 'Balling': Accuracy Mean = 0.8026315789473685, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.931995803829006, Std = 0.01607202306968518
# F1 Score: Mean = 0.9291846335316636, Std = 0.017971368293095917
# Precision: Mean = 0.9327198130212799, Std = 0.02034933351870707
# Recall: Mean = 0.931995803829006, Std = 0.01607202306968518
# ROC-AUC: Mean = 0.988341795701291, Std = 0.006274612703705483
# Evaluating model: LightGBM
# Inference Time: Mean = 0.001409 milliseconds, Std = 0.00241388 milliseconds
# Class 'Balling': Accuracy Mean = 0.7368421052631579, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9832402234636871, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.928, Std = 0.0
# Accuracy: Mean = 0.9239312876999739, Std = 0.012248332206353194
# F1 Score: Mean = 0.9203131570115295, Std = 0.014871102148576891
# Precision: Mean = 0.9252756356391394, Std = 0.01761230864287636
# Recall: Mean = 0.9239312876999739, Std = 0.012248332206353194
# ROC-AUC: Mean = 0.9886933612247131, Std = 0.0049662226530884
# Evaluating model: SVM
# Inference Time: Mean = 0.003194 milliseconds, Std = 0.000616854 milliseconds
# Class 'Balling': Accuracy Mean = 0.7631578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9497206703910615, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.888, Std = 0.0
# Accuracy: Mean = 0.8932205612378704, Std = 0.017195363500155787
# F1 Score: Mean = 0.8936595326195892, Std = 0.0155697618073557
# Precision: Mean = 0.9049106591065497, Std = 0.016782450412781
# Recall: Mean = 0.8932205612378704, Std = 0.017195363500155787
# ROC-AUC: Mean = 0.9851180515360565, Std = 0.005734651894115575
# Evaluating model: HistGB
# Inference Time: Mean = 0.003465 milliseconds, Std = 7.26175e-05 milliseconds
# Class 'Balling': Accuracy Mean = 0.7631578947368421, Std = 0.0
# Class 'Laser-off': Accuracy Mean = 0.9776536312849162, Std = 0.0
# Class 'Non-defective': Accuracy Mean = 0.952, Std = 0.0
# Accuracy: Mean = 0.9271702071859428, Std = 0.009005647837565075
# F1 Score: Mean = 0.9243577851159317, Std = 0.010074377602245386
# Precision: Mean = 0.9276301386143103, Std = 0.012347018466679932
# Recall: Mean = 0.9271702071859428, Std = 0.009005647837565075
# ROC-AUC: Mean = 0.9892348051235432, Std = 0.004249474567218653

# %%
final_results_df
# Out:
#         Dataset  KNN_Inference Time_mean  KNN_Inference Time_std  \
# 0  All Features                 0.006074                0.002835
# 1     Ablated 1                 0.004806                0.000774
# 2     Ablated 2                 0.003942                0.000469
# 3     Ablated 3                 0.003365                0.000551
# 4     Ablated 4                 0.003632                0.001189
#
#    KNN_Balling_mean  KNN_Balling_std  KNN_Degradation_mean  \
# 0          0.605263              0.0              0.918919
# 1          0.644737              0.0              0.918919
# 2          0.618421              0.0              0.918919
# 3          0.763158              0.0              0.945946
# 4          0.736842              0.0              0.945946
#
#    KNN_Degradation_std  KNN_LOF_mean  KNN_LOF_std  KNN_Laser-off_mean  ...  \
# 0                  0.0      0.363636          0.0            0.977654  ...
# 1                  0.0      0.272727          0.0            0.974860  ...
# 2                  0.0      0.318182          0.0            0.974860  ...
# 3                  0.0      0.363636          0.0            0.983240  ...
# 4                  0.0      0.454545          0.0            0.986034  ...
#
#    HistGB_Accuracy_mean  HistGB_Accuracy_std  HistGB_F1 Score_mean  \
# 0              0.922292             0.013370              0.918233
# 1              0.932009             0.013310              0.929319
# 2              0.927170             0.011538              0.923907
# 3              0.932009             0.013310              0.929160
# 4              0.927170             0.009006              0.924358
#
#    HistGB_F1 Score_std  HistGB_Precision_mean  HistGB_Precision_std  \
# 0             0.015240               0.923792              0.012450
# 1             0.014921               0.933157              0.017434
# 2             0.013282               0.930275              0.017551
# 3             0.014951               0.935508              0.016268
# 4             0.010074               0.927630              0.012347
#
#    HistGB_Recall_mean  HistGB_Recall_std  HistGB_ROC-AUC_mean  \
# 0            0.922292           0.013370             0.990876
# 1            0.932009           0.013310             0.991640
# 2            0.927170           0.011538             0.990659
# 3            0.932009           0.013310             0.990173
# 4            0.927170           0.009006             0.989235
#
#    HistGB_ROC-AUC_std
# 0            0.003711
# 1            0.002384
# 2            0.003327
# 3            0.003745
# 4            0.004249
#
# [5 rows x 243 columns]

# %%
print (final_results_df.columns)
# Out:
# Index(['Dataset', 'KNN_Inference Time_mean', 'KNN_Inference Time_std',
#        'KNN_Balling_mean', 'KNN_Balling_std', 'KNN_Degradation_mean',
#        'KNN_Degradation_std', 'KNN_LOF_mean', 'KNN_LOF_std',
#        'KNN_Laser-off_mean',
#        ...
#        'HistGB_Accuracy_mean', 'HistGB_Accuracy_std', 'HistGB_F1 Score_mean',
#        'HistGB_F1 Score_std', 'HistGB_Precision_mean', 'HistGB_Precision_std',
#        'HistGB_Recall_mean', 'HistGB_Recall_std', 'HistGB_ROC-AUC_mean',
#        'HistGB_ROC-AUC_std'],
#       dtype='object', length=243)

# %%
final_results_df.to_hdf(os.path.join(model_path, 'traditional_ML_evaluation_results.h5'), key='df', mode='w', format='table')

# %%
# %store final_results_df
# Out:
# Stored 'final_results_df' (DataFrame)

# %%
final_results_df.to_csv(os.path.join(model_path, 'traditional_ML_evaluation_results.csv'), index=False)

# %% [markdown]
# ## Evaluating inference time, file size, etc.

# %%
# Initialize the dictionary
model_paths = {}

# Generate the paths
for dataset_name in datasets:
    for model_name in model_names:
        file_name = f"{model_name}_{dataset_name}.joblib"
        full_path = os.path.join(model_path, file_name)
        model_paths[f"{model_name}_{dataset_name}"] = full_path

# %%
dataset_names = final_results_df['Dataset'].unique().tolist()
dataset_names
# Out:
# ['All Features', 'Ablated 1', 'Ablated 2', 'Ablated 3', 'Ablated 4']

# %%
def plot_model_sizes(paths, fontsize=14):
    model_sizes = {}
    for name, path in paths.items():
        model_sizes[name] = os.path.getsize(path) // 1024  # Size in KB

    sorted_model_sizes = {k: v for k, v in sorted(model_sizes.items(), key=lambda item: item[1])}

    plt.figure(figsize=(10, 6))
    plt.barh(list(sorted_model_sizes.keys()), list(sorted_model_sizes.values()), 
             color='skyblue', edgecolor='black', linewidth=0.5)
    plt.xlabel('Model Size (KB)', fontsize=fontsize+6, labelpad=10)
    plt.ylabel('Model', fontsize=fontsize+6)
    plt.xticks(fontsize=fontsize, rotation=45, ha='right')
    plt.yticks(fontsize=fontsize)
    plt.grid(which='both', linestyle='--', linewidth=0.5)
    # plt.show()

# Example usage:
# plot_model_sizes(model_paths)
# save_fig("model size comparisons")

# %% [markdown]
# ## Final results presentation

# %%
# Modify the evaluation metrics to include class-specific accuracies
evaluation_metrics = ['Accuracy', 'F1 Score', 'Recall', 'Precision', 'ROC-AUC', 'Inference Time', 
                      'Balling', 'Non-defective', "LOF", "Degradation", 'Laser-off']

# %%
def create_formatted_summary_table(df, metrics, top_n=3, selected_datasets=None, ranking_metric="Accuracy_mean"):
    # Initialize an empty DataFrame for the summary
    summary_df = pd.DataFrame(columns=['Dataset', 'Rank', 'Top Model', 'Model Size (KB)'] + metrics)

    # Calculate model sizes
    model_sizes = {}
    for name_path_key, path in model_paths.items():
        model_name, dataset_name = name_path_key.split('_')
        if dataset_name in selected_datasets:
            model_sizes[name_path_key] = os.path.getsize(path) // 1024  # Size in KB
    
    # Filter the DataFrame based on selected datasets if provided
    if selected_datasets is not None:
        df = df[df['Dataset'].isin(selected_datasets)]
    
    # Extract the model names from the columns
    model_names = set(col.split('_')[0] for col in df.columns if '_' in col)
    
    # Determine the order for sorting based on the ranking metric
    reverse_order = True  # Default is descending order
    if ranking_metric in ['Inference Time_mean', 'Model Size (KB)']:
        reverse_order = False  # For these metrics, smaller values are better
    
    # For each dataset, find the top N models based on the specified ranking metric and populate the summary table
    for i, row in df.iterrows():
        dataset = row['Dataset']
        scores = {}
        for model in model_names:
            metric_value = row.get(f"{model}_{ranking_metric}", np.nan)
            scores[model] = metric_value
        
        # Sort the models by the specified ranking metric and take the top N
        top_n_models = sorted(scores, key=scores.get, reverse=reverse_order)[:top_n]
        
        
        # Populate the summary table for this dataset and top N models
        for rank, model in enumerate(top_n_models, start=1):
            name_path_key = f"{model}_{dataset}"
            summary_row = {'Dataset': dataset, 'Rank': rank, 'Top Model': model, 'Model Size (KB)': model_sizes.get(name_path_key, 'N/A')}
            for metric in metrics:
                mean_val = row.get(f"{model}_{metric}_mean", np.nan) * 100  # Convert to percentage
                std_val = row.get(f"{model}_{metric}_std", np.nan) * 100  # Convert to percentage
                if not np.isnan(mean_val) and not np.isnan(std_val):
                    summary_row[metric] = f"{mean_val:.2f} ± {std_val:.4f}"  # Combine mean and std
                else:
                    summary_row[metric] = 'N/A'
                
            summary_df = summary_df.append(summary_row, ignore_index=True)
    
    return summary_df

# Create an example formatted summary table with top 3 models and all datasets
formatted_summary_df = create_formatted_summary_table(final_results_df, evaluation_metrics, top_n=3, selected_datasets=dataset_names, ranking_metric="Accuracy_mean")
formatted_summary_df
# Out:
#          Dataset Rank Top Model Model Size (KB)        Accuracy  \
# 0   All Features    1   XGBoost            2087  92.39 ± 0.8529
# 1   All Features    2        NN            2859  92.23 ± 1.1239
# 2   All Features    3    HistGB            1099  92.23 ± 1.3370
# 3      Ablated 1    1        NN            2805  93.69 ± 2.5927
# 4      Ablated 1    2   XGBoost            2103  93.36 ± 1.3040
# 5      Ablated 1    3    HistGB            1092  93.20 ± 1.3310
# 6      Ablated 2    1        NN            2725  93.52 ± 1.3723
# 7      Ablated 2    2   XGBoost            2159  93.04 ± 0.3928
# 8      Ablated 2    3  LightGBM             963  92.88 ± 0.9608
# 9      Ablated 3    1    HistGB            1129  93.20 ± 1.3310
# 10     Ablated 3    2   XGBoost            2217  92.88 ± 1.4120
# 11     Ablated 3    3        NN            2574  92.71 ± 2.0724
# 12     Ablated 4    1   XGBoost            2260  93.20 ± 1.6072
# 13     Ablated 4    2    HistGB            1177  92.72 ± 0.9006
# 14     Ablated 4    3        NN            2521  92.55 ± 1.2138
#
#           F1 Score          Recall       Precision         ROC-AUC  \
# 0   92.10 ± 1.0441  92.39 ± 0.8529  92.35 ± 1.4077  98.96 ± 0.3823
# 1   92.02 ± 1.2802  92.23 ± 1.1239  92.13 ± 1.4321  99.05 ± 0.3741
# 2   91.82 ± 1.5240  92.23 ± 1.3370  92.38 ± 1.2450  99.09 ± 0.3711
# 3   93.64 ± 2.6850  93.69 ± 2.5927  94.01 ± 2.6574  99.14 ± 0.5442
# 4   93.15 ± 1.3887  93.36 ± 1.3040  93.48 ± 1.3797  98.93 ± 0.3830
# 5   92.93 ± 1.4921  93.20 ± 1.3310  93.32 ± 1.7434  99.16 ± 0.2384
# 6   93.29 ± 1.5554  93.52 ± 1.3723  93.52 ± 1.5002  99.18 ± 0.5407
# 7   92.85 ± 0.5273  93.04 ± 0.3928  92.96 ± 0.7274  98.89 ± 0.6092
# 8   92.53 ± 1.1695  92.88 ± 0.9608  93.16 ± 1.4689  98.94 ± 0.4518
# 9   92.92 ± 1.4951  93.20 ± 1.3310  93.55 ± 1.6268  99.02 ± 0.3745
# 10  92.47 ± 1.7330  92.88 ± 1.4120  93.06 ± 1.9571  98.86 ± 0.8565
# 11  92.37 ± 2.2061  92.71 ± 2.0724  92.80 ± 2.3370  99.26 ± 0.4125
# 12  92.92 ± 1.7971  93.20 ± 1.6072  93.27 ± 2.0349  98.83 ± 0.6275
# 13  92.44 ± 1.0074  92.72 ± 0.9006  92.76 ± 1.2347  98.92 ± 0.4249
# 14  92.20 ± 1.4419  92.55 ± 1.2138  92.49 ± 1.6965  99.19 ± 0.2910
#
#    Inference Time         Balling   Non-defective             LOF  \
# 0   0.54 ± 1.5851  76.32 ± 0.0000  92.80 ± 0.0000  45.45 ± 0.0000
# 1   0.10 ± 0.0136  73.68 ± 0.0000  93.60 ± 0.0000  54.55 ± 0.0000
# 2   0.36 ± 0.0966  75.00 ± 0.0000  92.80 ± 0.0000  45.45 ± 0.0000
# 3   0.10 ± 0.0078  86.84 ± 0.0000  93.60 ± 0.0000  68.18 ± 0.0000
# 4   0.61 ± 0.5019  80.26 ± 0.0000  95.20 ± 0.0000  50.00 ± 0.0000
# 5   0.34 ± 0.0127  78.95 ± 0.0000  94.40 ± 0.0000  50.00 ± 0.0000
# 6   0.10 ± 0.0078  81.58 ± 0.0000  92.80 ± 0.0000  59.09 ± 0.0000
# 7   0.58 ± 0.7073  78.95 ± 0.0000  93.60 ± 0.0000  50.00 ± 0.0000
# 8   0.10 ± 0.0391  77.63 ± 0.0000  93.60 ± 0.0000  45.45 ± 0.0000
# 9   0.37 ± 0.0138  81.58 ± 0.0000  93.60 ± 0.0000  50.00 ± 0.0000
# 10  0.95 ± 0.5921  80.26 ± 0.0000  93.60 ± 0.0000  45.45 ± 0.0000
# 11  0.10 ± 0.0090  77.63 ± 0.0000  94.40 ± 0.0000  45.45 ± 0.0000
# 12  0.54 ± 0.5868  80.26 ± 0.0000  92.80 ± 0.0000  54.55 ± 0.0000
# 13  0.35 ± 0.0073  76.32 ± 0.0000  95.20 ± 0.0000  54.55 ± 0.0000
# 14  0.10 ± 0.0098  76.32 ± 0.0000  94.40 ± 0.0000  50.00 ± 0.0000
#
#        Degradation       Laser-off
# 0   94.59 ± 0.0000  98.32 ± 0.0000
# 1   91.89 ± 0.0000  98.04 ± 0.0000
# 2   94.59 ± 0.0000  98.32 ± 0.0000
# 3   89.19 ± 0.0000  97.21 ± 0.0000
# 4   94.59 ± 0.0000  98.04 ± 0.0000
# 5   94.59 ± 0.0000  98.32 ± 0.0000
# 6   89.19 ± 0.0000  98.88 ± 0.0000
# 7   91.89 ± 0.0000  98.60 ± 0.0000
# 8   94.59 ± 0.0000  98.60 ± 0.0000
# 9   94.59 ± 0.0000  98.04 ± 0.0000
# 10  94.59 ± 0.0000  98.04 ± 0.0000
# 11  94.59 ± 0.0000  98.04 ± 0.0000
# 12  94.59 ± 0.0000  98.32 ± 0.0000
# 13  91.89 ± 0.0000  97.77 ± 0.0000
# 14  94.59 ± 0.0000  97.77 ± 0.0000

# %%
# Function to create bar charts for the top 5 models based on a particular metric
def create_bar_chart(df, metric_mean):
    # Extract the model names from the columns
    model_names = set(col.split('_')[0] for col in df.columns if '_' in col)
    
    # Find the top 5 models for each dataset
    top_models_dict = {}
    for i, row in df.iterrows():
        scores = {}
        for model in model_names:
            mean_metric = row[f"{model}_{metric_mean}"]
            scores[model] = mean_metric
        
        top_models = sorted(scores, key=scores.get, reverse=True)[:10]
        top_models_dict[row['Dataset']] = top_models
    
    # Create the bar chart
    for dataset, top_models in top_models_dict.items():
        scores = [df.loc[df['Dataset'] == dataset, f"{model}_{metric_mean}"].values[0] for model in top_models]
        plt.figure(figsize=(10, 6))
        sns.barplot(x=top_models, y=scores)
        plt.title(f"Top 5 Models Based on {metric_mean} for {dataset}")
        plt.ylabel(metric_mean)
        plt.xticks(fontsize=14, rotation=45, ha='right')
        plt.yticks(fontsize=14, rotation=0, ha='right')
        
        save_fig(f"metrics_heatmaps/{metric_mean}.png")
        # plt.show()

# %%
# Create bar charts for top 5 models based on 'Accuracy_mean'
create_bar_chart(final_results_df, 'Accuracy_mean')
# Out:
# Saving figure metrics_heatmaps/Accuracy_mean.png
# Saving figure metrics_heatmaps/Accuracy_mean.png
# Saving figure metrics_heatmaps/Accuracy_mean.png
# Saving figure metrics_heatmaps/Accuracy_mean.png
# Saving figure metrics_heatmaps/Accuracy_mean.png

# %%
# Function to create heatmaps
def create_heatmap(df, metric_mean, fontsize=16, title_pad=20, label_pad=15, figsize=(12, 8), 
                   colorbar_length=0.9, grid_thickness=0.6):
    # Extract the model names from the columns
    model_names = set(col.split('_')[0] for col in df.columns if '_' in col)
    
    # Create a dataframe suitable for heatmaps
    heatmap_df = pd.DataFrame(index=df['Dataset'], columns=model_names)
    for model in model_names:
        heatmap_df[model] = df[f"{model}_{metric_mean}"].values

    # Reorder the columns based on descending accuracy on the "All Features" dataset
    all_features_accuracy = heatmap_df.loc['All Features'].sort_values(ascending=False)
    heatmap_df = heatmap_df[all_features_accuracy.index]
    
    # Create the heatmap
    plt.figure(figsize=figsize)
    ax = sns.heatmap(heatmap_df, annot=True, cmap="YlGnBu", fmt=".3f", linewidths=grid_thickness, 
                     linecolor='black', cbar_kws={"shrink": colorbar_length}, annot_kws={"size": fontsize-4})
    
    # Set title and labels with font sizes and paddings
    plt.title(f"Heatmap Based on {metric_mean}", fontsize=fontsize+6, pad=title_pad)
    plt.xlabel("Models", fontsize=fontsize+6, labelpad=label_pad)
    plt.ylabel("Datasets", fontsize=fontsize+6, labelpad=label_pad)
    plt.xticks(fontsize=fontsize, rotation=45, ha='right')
    plt.yticks(fontsize=fontsize, rotation=0, ha='right')

# %%
# Create a function to run create_heatmap for each evaluation metric and save the figure
def run_and_save_heatmaps(df, metrics, save_path, **kwargs):
    for metric in metrics:
        create_heatmap(df, f"{metric}_mean", **kwargs)
        save_fig(f"{save_path}/{metric}_heatmap.png")

# Uncomment the line below to run the function.
run_and_save_heatmaps(final_results_df, evaluation_metrics, save_path="metrics_heatmaps")
# Out:
# Saving figure metrics_heatmaps/Accuracy_heatmap.png
# Saving figure metrics_heatmaps/F1 Score_heatmap.png
# Saving figure metrics_heatmaps/Recall_heatmap.png
# Saving figure metrics_heatmaps/Precision_heatmap.png
# Saving figure metrics_heatmaps/ROC-AUC_heatmap.png
# Saving figure metrics_heatmaps/Inference Time_heatmap.png
# Saving figure metrics_heatmaps/Balling_heatmap.png
# Saving figure metrics_heatmaps/Non-defective_heatmap.png
# Saving figure metrics_heatmaps/LOF_heatmap.png
# Saving figure metrics_heatmaps/Degradation_heatmap.png
# Saving figure metrics_heatmaps/Laser-off_heatmap.png
